# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('/content/Flight_satisfaction.csv')

# %%
df.sample()
# Out:
#          Unnamed: 0       id Gender   Customer Type   Age   Type of Travel  \
# 13506 -98238.512969  18914.0    NaN  Loyal Customer  24.0  Personal Travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 13506   Eco            448.0                    2.0
#
#        Departure/Arrival time convenient  ...  Inflight entertainment  \
# 13506                                2.0  ...                     1.0
#
#        On-board service  Leg room service  Baggage handling  Checkin service  \
# 13506               3.0               NaN               NaN              4.0
#
#        Inflight service  Cleanliness  Departure Delay in Minutes  \
# 13506               2.0          1.0                         2.0
#
#        Arrival Delay in Minutes             satisfaction
# 13506                       0.0  neutral or dissatisfied
#
# [1 rows x 25 columns]

# %% [markdown]
# # Data cleaning and handeling outliers in data

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                           15096
# id                                   15062
# Gender                               18746
# Customer Type                        18940
# Age                                  15075
# Type of Travel                       18673
# Class                                18844
# Flight Distance                      15157
# Inflight wifi service                15250
# Departure/Arrival time convenient    15013
# Ease of Online booking               14984
# Gate location                        15078
# Food and drink                       15219
# Online boarding                      15108
# Seat comfort                         14957
# Inflight entertainment               15254
# On-board service                     15085
# Leg room service                     15185
# Baggage handling                     15183
# Checkin service                      15182
# Inflight service                     15027
# Cleanliness                          15137
# ...

# %%
df.isnull().mean()*100
# Out:
# Unnamed: 0                           14.528796
# id                                   14.496073
# Gender                               18.041654
# Customer Type                        18.228365
# Age                                  14.508585
# Type of Travel                       17.971397
# Class                                18.135972
# Flight Distance                      14.587504
# Inflight wifi service                14.677010
# Departure/Arrival time convenient    14.448914
# Ease of Online booking               14.421004
# Gate location                        14.511472
# Food and drink                       14.647174
# Online boarding                      14.540345
# Seat comfort                         14.395018
# Inflight entertainment               14.680859
# On-board service                     14.518209
# Leg room service                     14.614452
# Baggage handling                     14.612527
# Checkin service                      14.611565
# ...

# %%
import missingno as msno
msno.bar(df)
# Out:
# <Axes: >

# %%
df['id'].value_counts()
# Out:
# id
#  252058.647849    10424
# -122263.290225    10356
#  108098.000000        1
#  12804.000000         1
#  119815.000000        1
#                   ...
#  105957.000000        1
#  77834.000000         1
#  36492.000000         1
#  12904.000000         1
#  19224.000000         1
# Name: count, Length: 68064, dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age', 'Type of Travel',
#        'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
sns.boxplot(x='id',data=df)
# Out:
# <Axes: xlabel='id'>

# %%
df['id']=df['id'].fillna(df['id'].mean())

# %%
df['id'].isnull().sum()
# Out:
# np.int64(0)

# %%
sns.boxplot(x='id',data=df)
# Out:
# <Axes: xlabel='id'>

# %%
Q1 = df['id'].quantile(0.25)
Q3 = df['id'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['id'] = np.where(df['id'] < lower_bound, lower_bound,
                       np.where(df['id'] > upper_bound, upper_bound, df['id']))

# %%
sns.boxplot(x='id',data=df)
# Out:
# <Axes: xlabel='id'>

# %%
df['Gender']=df['Gender'].fillna(df['Gender'].mode()[0])

# %%
df['Gender'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Customer Type']=df['Customer Type'].fillna(df['Customer Type'].mode()[0])

# %%
df['Customer Type'].isnull().sum()
# Out:
# np.int64(0)

# %%
sns.boxplot(x='Age',data=df)
# Out:
# <Axes: xlabel='Age'>

# %%
df['Age']=df['Age'].fillna(df['Age'].median())
df['Age'].isnull().sum()
# Out:
# np.int64(0)

# %%
sns.boxplot(x='Age',data=df)
# Out:
# <Axes: xlabel='Age'>

# %%
Q1 = df['Age'].quantile(0.25)
Q3 = df['Age'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['Age'] = np.where(df['Age'] < lower_bound, lower_bound,
                       np.where(df['Age'] > upper_bound, upper_bound, df['Age']))

# %%
sns.boxplot(x='Age',data=df)
# Out:
# <Axes: xlabel='Age'>

# %%
df['Type of Travel']=df['Type of Travel'].fillna(df['Type of Travel'].mode()[0])
df['Type of Travel'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Class']=df['Class'].fillna(df['Class'].mode()[0])
df['Class'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Flight Distance']=df['Flight Distance'].fillna(df['Flight Distance'].mode()[0])
df['Flight Distance'].isnull().sum()
# Out:
# np.int64(0)

# %%
sns.boxplot(x=df['Flight Distance'])
# Out:
# <Axes: xlabel='Flight Distance'>

# %%
sns.boxplot(x=df['Inflight wifi service'])
# Out:
# <Axes: xlabel='Inflight wifi service'>

# %%
df['Inflight wifi service']=df['Inflight wifi service'].fillna(df['Inflight wifi service'].median())
df['Inflight wifi service'].isnull().sum()
# Out:
# np.int64(0)

# %%
Q1 = df['Inflight wifi service'].quantile(0.25)
Q3 = df['Inflight wifi service'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['Inflight wifi service'] = np.where(df['Inflight wifi service'] < lower_bound, lower_bound,
                       np.where(df['Inflight wifi service'] > upper_bound, upper_bound, df['Inflight wifi service']))
sns.boxplot(x=df['Inflight wifi service'])
# Out:
# <Axes: xlabel='Inflight wifi service'>

# %%
sns.boxplot(x=df['Departure/Arrival time convenient'])
# Out:
# <Axes: xlabel='Departure/Arrival time convenient'>

# %%
df['Departure/Arrival time convenient']=df['Departure/Arrival time convenient'].fillna(df['Departure/Arrival time convenient'].mean())
df['Departure/Arrival time convenient'].isnull().sum()
# Out:
# np.int64(0)

# %%
sns.boxplot(x=df['Ease of Online booking'])
# Out:
# <Axes: xlabel='Ease of Online booking'>

# %%
df['Ease of Online booking']=df['Ease of Online booking'].fillna(df['Ease of Online booking'].median())
df['Ease of Online booking'].isnull().sum()
# Out:
# np.int64(0)

# %%
Q1 = df['Ease of Online booking'].quantile(0.25)
Q3 = df['Ease of Online booking'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['Ease of Online booking'] = np.where(df['Ease of Online booking'] < lower_bound, lower_bound,
                       np.where(df['Ease of Online booking'] > upper_bound, upper_bound, df['Ease of Online booking']))
sns.boxplot(x=df['Ease of Online booking'])
# Out:
# <Axes: xlabel='Ease of Online booking'>

# %%
sns.boxplot(x=df['Gate location'])
# Out:
# <Axes: xlabel='Gate location'>

# %%
df['Gate location']=df['Gate location'].fillna(df['Gate location'].median())
df['Gate location'].isnull().sum()
# Out:
# np.int64(0)

# %%
Q1 = df['Gate location'].quantile(0.25)
Q3 = df['Gate location'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['Gate location'] = np.where(df['Gate location'] < lower_bound, lower_bound,
                       np.where(df['Gate location'] > upper_bound, upper_bound, df['Gate location']))
sns.boxplot(x=df['Gate location'])
# Out:
# <Axes: xlabel='Gate location'>

# %%
sns.boxplot(x=df['Food and drink'])
# Out:
# <Axes: xlabel='Food and drink'>

# %%
df['Food and drink']=df['Food and drink'].fillna(df['Food and drink'].median())
df['Food and drink'].isnull().sum()
# Out:
# np.int64(0)

# %%
Q1 = df['Food and drink'].quantile(0.25)
Q3 = df['Food and drink'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df['Food and drink'] = np.where(df['Food and drink'] < lower_bound, lower_bound,
                       np.where(df['Food and drink'] > upper_bound, upper_bound, df['Food and drink']))
sns.boxplot(x=df['Food and drink'])
# Out:
# <Axes: xlabel='Food and drink'>

# %%
features=['Online boarding,Seat comfort,Inflight entertainment,On-board service,Leg room service,Baggage handling,Checkin service,Inflight service,Cleanliness,Departure Delay in Minutes,Arrival Delay in Minutes']

# %%
features = [
    'Online boarding', 'Seat comfort', 'Inflight entertainment', 'On-board service',
    'Leg room service', 'Baggage handling', 'Checkin service', 'Inflight service',
    'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes'
]

for feature in features:
    plt.figure(figsize=(8, 4))
    sns.boxplot(x=df[feature])
    plt.title(f'Box Plot of {feature}')
    plt.xlabel(feature)
    plt.tight_layout()
    plt.show()

# %%
features = ['Unnamed: 0','Online boarding', 'Seat comfort', 'Inflight entertainment', 'On-board service',
    'Leg room service', 'Baggage handling', 'Checkin service', 'Inflight service',
    'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes'
]
for feature in features:
  df[feature]=df[feature].fillna(df[feature].median())
df.isnull().sum()
# Out:
# Unnamed: 0                               0
# id                                       0
# Gender                                   0
# Customer Type                            0
# Age                                      0
# Type of Travel                           0
# Class                                    0
# Flight Distance                          0
# Inflight wifi service                    0
# Departure/Arrival time convenient        0
# Ease of Online booking                   0
# Gate location                            0
# Food and drink                           0
# Online boarding                          0
# Seat comfort                             0
# Inflight entertainment                   0
# On-board service                         0
# Leg room service                         0
# Baggage handling                         0
# Checkin service                          0
# Inflight service                         0
# Cleanliness                              0
# ...

# %%
df['satisfaction']=df['satisfaction'].fillna(df['satisfaction'].mode()[0])
df['satisfaction'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                           0
# id                                   0
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# ...

# %%
plt.pie(df['Gender'].value_counts(), labels=df['Gender'].value_counts().index, autopct='%1.1f%%')
plt.title('Pie Chart of Gender')
# Out:
# Text(0.5, 1.0, 'Pie Chart of Gender')

# %%
sns.countplot(x=df['satisfaction'], hue=df['Gender'])
# Out:
# <Axes: xlabel='satisfaction', ylabel='count'>

# %%
sns.barplot(x=df['Class'], y=df['Online boarding'])
# Out:
# <Axes: xlabel='Class', ylabel='Online boarding'>

# %% [markdown]
# # The max online bookings are done in business class

# %%
sns.barplot(x=df['Class'], y=df['Online boarding'],hue=df['Gender'])
# Out:
# <Axes: xlabel='Class', ylabel='Online boarding'>

# %% [markdown]
# # the maximum online bookings are done in businness class and the gender male is lessthan female but  booking of business class by male and female are equal

# %%
sns.histplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
df['Age'].max()
# Out:
# 91.0

# %% [markdown]
# # The maximum age of persons are travel is 40 and 91

# %%
sns.countplot(x=df['Class'], hue=df['Leg room service'])
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %% [markdown]
# # the maximum legroom services are booking in business class and after Eco class

# %%
sns.countplot(x=df['Class'], hue=df['On-board service'])
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %% [markdown]
# # The On-board service will also maximum booking will done by business class and after Eco

# %%
sns.barplot(x=df['Class'], y=df['Arrival Delay in Minutes'])
# Out:
# <Axes: xlabel='Class', ylabel='Arrival Delay in Minutes'>

# %% [markdown]
# # compare to Eco and eco plus the business class is less time for Arrival Delay in Minutes

# %%
sns.barplot(x=df['Class'], y=df['Inflight entertainment'])
# Out:
# <Axes: xlabel='Class', ylabel='Inflight entertainment'>

# %% [markdown]
# # There is some small diggerence in eco plus and eco compare to  business class in Inflight entertainment

# %%
sns.barplot(x=df['Class'], y=df['Ease of Online booking'])
# Out:
# <Axes: xlabel='Class', ylabel='Ease of Online booking'>

# %% [markdown]
# # the 3 types of class is same for Ease of Online booking but litle bit more by business class

# %%
sns.barplot(x=df['Class'], y=df['Online boarding'],hue=df['Food and drink'])
# Out:
# <Axes: xlabel='Class', ylabel='Online boarding'>

# %% [markdown]
# # the online booking persons where give rating food is same in 3 class

# %%
plt.pie(df['Type of Travel'].value_counts(), labels=df['Type of Travel'].value_counts().index, autopct='%1.1f%%')
plt.title('Pie Chart of Type of Travel')
# Out:
# Text(0.5, 1.0, 'Pie Chart of Type of Travel')

# %%
sns.countplot(x=df['Class'], hue=df['Type of Travel'])
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %% [markdown]
# # mostly passengers are book Eco class for personal Travel and passengers who are for business Travel they book business class

# %%
sns.barplot(x=df['Class'], y=df['Inflight service'])
# Out:
# <Axes: xlabel='Class', ylabel='Inflight service'>

# %% [markdown]
# # the rating of services in classes in flight is same

# %%
sns.barplot(x=df['Class'], y=df['Cleanliness'])
# Out:
# <Axes: xlabel='Class', ylabel='Cleanliness'>

# %% [markdown]
# # the rating of cleaning services in classes in flight is same

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x=df['Class'], hue=df['Online boarding'])
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %% [markdown]
# # Based on this visualizations  Female are 60% and male are 40% traveling in flight ,the services of food ,cleaning ,checkin are same in classes but  little bit more comforts are present in business class.
# # The legroom service ,Inflight service,etc are same but little bit votes are gained by business class.
# # There are 2 types of travelere are travel mostly  personal travelers are prefering Eco class and business travelers are travel in Business class.
# #  conclusion if you are travel in a flight based on the travel like business purpose or personal travel ,if you are a personal traveler you will consider the Eco class and if you are a travel for business purpose you will consider the business class the comforta are same in Eco and business class.
